# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/Border_Crossing_Entry_Data.csv')
df.head()
# Out:
#        Port Name    State  Port Code            Border    Date Measure  Value  \
# 0           Roma    Texas       2310  US-Mexico Border  Dec-23   Buses     46
# 1        Del Rio    Texas       2302  US-Mexico Border  Dec-23  Trucks   6552
# 2           Roma    Texas       2310  US-Mexico Border  Nov-23  Trucks   3753
# 3        Douglas  Arizona       2601  US-Mexico Border  Oct-23   Buses     13
# 4  Beecher Falls  Vermont        206  US-Canada Border  Aug-23  Trucks    422
#
#    Latitude  Longitude                          Point
# 0    26.404    -99.019   POINT (-99.018981 26.403928)
# 1    29.327   -100.928  POINT (-100.927612 29.326784)
# 2    26.404    -99.019   POINT (-99.018981 26.403928)
# 3    31.334   -109.560  POINT (-109.560344 31.334043)
# 4    45.013    -71.505   POINT (-71.505309 45.013411)

# %%
df.tail()
# Out:
#           Port Name       State  Port Code            Border    Date  \
# 395633       Norton     Vermont        211  US-Canada Border  Sep-24
# 395634      Laurier  Washington       3016  US-Canada Border  Sep-24
# 395635  Trout River    New York        715  US-Canada Border  Sep-24
# 395636      El Paso       Texas       2402  US-Mexico Border  Sep-24
# 395637       Calais       Maine        115  US-Canada Border  Sep-24
#
#                         Measure  Value  Latitude  Longitude  \
# 395633  Truck Containers Loaded    668    45.011    -71.793
# 395634  Truck Containers Loaded    162    49.000   -118.224
# 395635                   Trains     46    44.992    -74.308
# 395636           Bus Passengers  20729    31.764   -106.451
# 395637                   Trains      7    45.189    -67.275
#
#                                 Point
# 395633   POINT (-71.793219 45.010771)
# 395634  POINT (-118.223777 49.000083)
# 395635   POINT (-74.308172 44.992058)
# ...

# %%
df.describe()
# Out:
#            Port Code         Value       Latitude      Longitude
# count  395638.000000  3.956380e+05  395638.000000  395638.000000
# mean     2446.496201  2.884933e+04      43.974092     -99.730139
# std      1204.138442  1.495808e+05       8.151891      18.259105
# min       101.000000  0.000000e+00      25.952000    -141.001000
# 25%      2304.000000  0.000000e+00      42.999000    -114.728000
# 50%      3012.000000  1.430000e+02      48.122000    -101.628000
# 75%      3401.000000  2.984000e+03      49.000000     -89.585000
# max      3814.000000  4.447374e+06      62.615000     -66.980000

# %%
df.describe(include="all")
# Out:
#        Port Name         State      Port Code            Border    Date  \
# count     395638        395638  395638.000000            395638  395638
# unique       116            14            NaN                 2     345
# top     Eastport  North Dakota            NaN  US-Canada Border  Sep-10
# freq        6662         63844            NaN            302378    1356
# mean         NaN           NaN    2446.496201               NaN     NaN
# std          NaN           NaN    1204.138442               NaN     NaN
# min          NaN           NaN     101.000000               NaN     NaN
# 25%          NaN           NaN    2304.000000               NaN     NaN
# 50%          NaN           NaN    3012.000000               NaN     NaN
# 75%          NaN           NaN    3401.000000               NaN     NaN
# max          NaN           NaN    3814.000000               NaN     NaN
#
#                   Measure         Value       Latitude      Longitude  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395638 entries, 0 to 395637
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Port Name  395638 non-null  object
#  1   State      395638 non-null  object
#  2   Port Code  395638 non-null  int64
#  3   Border     395638 non-null  object
#  4   Date       395638 non-null  object
#  5   Measure    395638 non-null  object
#  6   Value      395638 non-null  int64
#  7   Latitude   395638 non-null  float64
#  8   Longitude  395638 non-null  float64
#  9   Point      395638 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 30.2+ MB

# %%
df.isnull()
# Out:
#         Port Name  State  Port Code  Border   Date  Measure  Value  Latitude  \
# 0           False  False      False   False  False    False  False     False
# 1           False  False      False   False  False    False  False     False
# 2           False  False      False   False  False    False  False     False
# 3           False  False      False   False  False    False  False     False
# 4           False  False      False   False  False    False  False     False
# ...           ...    ...        ...     ...    ...      ...    ...       ...
# 395633      False  False      False   False  False    False  False     False
# 395634      False  False      False   False  False    False  False     False
# 395635      False  False      False   False  False    False  False     False
# 395636      False  False      False   False  False    False  False     False
# 395637      False  False      False   False  False    False  False     False
#
#         Longitude  Point
# ...

# %%
y=df['Point']
y
# Out:
# 0          POINT (-99.018981 26.403928)
# 1         POINT (-100.927612 29.326784)
# 2          POINT (-99.018981 26.403928)
# 3         POINT (-109.560344 31.334043)
# 4          POINT (-71.505309 45.013411)
#                       ...
# 395633     POINT (-71.793219 45.010771)
# 395634    POINT (-118.223777 49.000083)
# 395635     POINT (-74.308172 44.992058)
# 395636    POINT (-106.451188 31.764363)
# 395637     POINT (-67.275381 45.188548)
# Name: Point, Length: 395638, dtype: object

# %%
x=df.drop("Point", axis=1)
x
# Out:
#             Port Name       State  Port Code            Border    Date  \
# 0                Roma       Texas       2310  US-Mexico Border  Dec-23
# 1             Del Rio       Texas       2302  US-Mexico Border  Dec-23
# 2                Roma       Texas       2310  US-Mexico Border  Nov-23
# 3             Douglas     Arizona       2601  US-Mexico Border  Oct-23
# 4       Beecher Falls     Vermont        206  US-Canada Border  Aug-23
# ...               ...         ...        ...               ...     ...
# 395633         Norton     Vermont        211  US-Canada Border  Sep-24
# 395634        Laurier  Washington       3016  US-Canada Border  Sep-24
# 395635    Trout River    New York        715  US-Canada Border  Sep-24
# 395636        El Paso       Texas       2402  US-Mexico Border  Sep-24
# 395637         Calais       Maine        115  US-Canada Border  Sep-24
#
#                         Measure  Value  Latitude  Longitude
# ...

# %%
plt.hist(df['Border'], color='green', bins=20, edgecolor='white')
plt.title('Illigal Border Crossing')
plt.xlabel('Border')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# **Based on the graphical presentation, we can deduce that, more security should be deploy at the US-Canada Border.**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split (x,y, test_size=0.2, random_state=100)
x_train
# Out:
#                      Port Name         State  Port Code            Border  \
# 154998                   Alcan        Alaska       3104  US-Canada Border
# 368271               Vanceboro         Maine        105  US-Canada Border
# 304857                Columbus    New Mexico       2406  US-Mexico Border
# 191641  Champlain Rouses Point      New York        712  US-Canada Border
# 82008                 Hansboro  North Dakota       3415  US-Canada Border
# ...                        ...           ...        ...               ...
# 339799               Van Buren         Maine        108  US-Canada Border
# 253799                 Fortuna  North Dakota       3417  US-Canada Border
# 210755                Baudette     Minnesota       3424  US-Canada Border
# 56088                   Blaine    Washington       3004  US-Canada Border
# 300552                 Skagway        Alaska       3103  US-Canada Border
#
#           Date                      Measure   Value  Latitude  Longitude
# ...

# %%
x_test
# Out:
#              Port Name         State  Port Code            Border    Date  \
# 391032         St John  North Dakota       3405  US-Canada Border  Mar-24
# 232381         Del Rio         Texas       2302  US-Mexico Border  Jun-07
# 104245        Danville    Washington       3012  US-Canada Border  Oct-13
# 367505    Dalton Cache        Alaska       3106  US-Canada Border  Nov-96
# 282412           Sumas    Washington       3009  US-Canada Border  Oct-02
# ...                ...           ...        ...               ...     ...
# 380266         St John  North Dakota       3405  US-Canada Border  Jul-96
# 165168           Maida  North Dakota       3416  US-Canada Border  Apr-10
# 287269  Alexandria Bay      New York        708  US-Canada Border  Oct-02
# 121403         Detroit      Michigan       3801  US-Canada Border  Sep-12
# 175218        Richford       Vermont        203  US-Canada Border  Jun-10
#
#                        Measure  Value  Latitude  Longitude
# ...

# %%
from sklearn.model_selection import LinearRegression
lr = LinearnRegression()
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-57-24e0d1da79dd> in <cell line: 1>()
# ----> 1 from sklearn.model_selection import LinearRegression
#       2 lr = LinearnRegression()
#       3 lr.fit(x_train,y_train)
#
# ImportError: cannot import name 'LinearRegression' from 'sklearn.model_selection' (/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
y_lr_train_pred=lr.predict(x_train)
y_lr_test_pred=lr.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-a1220b8e9944> in <cell line: 1>()
# ----> 1 y_lr_train_pred=lr.predict(x_train)
#       2 y_lr_test_pred=lr.predict(x_test)
#
# NameError: name 'lr' is not defined
